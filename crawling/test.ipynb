# %%
import requests
from bs4 import BeautifulSoup

# %%
import re

# %%
basic_url = "https://www.yes24.com/"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36'}

init_url = "https://www.yes24.com/24/Category/Display/001001025007?PageNumber={}"

res = requests.get(init_url.format(1), headers= headers)
res
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(res.text, 'html.parser')
max_page_num = int(re.search(r'\d+$', soup.select_one('div.yesUI_pagenS>a.end')['href']).group(0))
max_page_num
# Out:
# 598

# %%
def get_basic_info(page_url):
    print(f'Get basic information in {page_url}')
    res = requests.get(page_url, headers= headers)
    soup = BeautifulSoup(res.text, 'html.parser')
    boxes = soup.select('div.cCont_goodsSet')

    basic_info_list = []
    for i, box in enumerate(boxes):
        print(i)
        # title box
        name_box = box.select_one('div.goods_name')

        # title, url
        title_box = name_box.select_one('a')
        title_text = title_box.text.strip()
        book_url = basic_url + title_box['href']

        # full_name
        name_front = name_box.select_one('span.gd_nameF').text
        name_end = name_box.select_one('span.gd_nameE').text
        name_feature = name_box.select_one('span.gd_feature').text
        full_name = ' '.join([name_front, title_text, name_end, name_feature])

        # pub_box
        pub_box = box.select_one('div.goods_pubGrp')
        authors = pub_box.select_one('span.goods_auth').text.strip()
        # $$$ 저자, 역자 나누기
        # $$$ 정보 더 보기/감추기 <- 클렌징
        publisher = pub_box.select_one('span.goods_pub').text

        print(f"title: [{title_text}]")
        print("full name:", full_name)
        print('url:', book_url)
        print('authors:', authors)
        print('publisher:', publisher)
        print('*'*10+'\n')

        basic_info_list.append([title_text, full_name, book_url, authors, publisher])
    return basic_info_list

# %%
for i in range(1, max_page_num+1):
    get_basic_info(init_url.format(i))
    break
# Out:
# Get basic information in https://www.yes24.com/24/Category/Display/001001025007?PageNumber=1
# 0
# title: [트렌드 코리아 2025]
# full name:  트렌드 코리아 2025 2025 대한민국 소비트렌드 전망
# url: https://www.yes24.com//Product/Goods/133213071
# authors: 김난도,전미영,최지혜,권정윤,한다혜,이혜원,이준영,이향은,추예린,전다현 저
# publisher: 미래의창
# **********
#
# 1
# title: [자본주의]
# full name: EBS 다큐프라임 자본주의 쉬지 않고 일하는데 나는 왜 이렇게 살기 힘든가
# url: https://www.yes24.com//Product/Goods/11081680
# authors: 정지은,고희정 저
# publisher: 가나출판사
# **********
#
# 2
# title: [대한경제부흥회]
# full name:  대한경제부흥회 우리는 왜 돈을 못 버는가
# url: https://www.yes24.com//Product/Goods/130495190
# authors: 이광수,박시동,안진걸 저
# publisher: 지와인
# **********
#
# 3
# title: [시대예보 : 호명사회]
# full name:  시대예보 : 호명사회
# url: https://www.yes24.com//Product/Goods/133236068
# authors: 송길영 저
# publisher: 교보문고
# **********
#
# 4
# title: [모두의 금리]
# full name:  모두의 금리 흔들리는 부의 공식과 금리의 황금 비밀
# url: https://www.yes24.com//Product/Goods/133282498
# authors: 조원경 저
# publisher: 에프엔미디어
# **********
#
# 5
# title: [피벗의 시대 2025년 경제전망]
# full name:  피벗의 시대 2025년 경제전망 2025년을 결정지을 18대 경제트렌드
# url: https://www.yes24.com//Product/Goods/133233432
# authors: 김광석 저
# publisher: 이든하우스
# **********
#
# 6
# title: [레버리지]
# full name:  레버리지 자본주의 속에 숨겨진 부의 비밀   [ 20만 부 기념 블랙 에디션, 양장 ]
# url: https://www.yes24.com//Product/Goods/117389523
# authors: 롭 무어 저/김유미 역
# publisher: 다산북스
# **********
#
# 7
# title: [부의 추월차선 (10주년 스페셜 에디션)]
# full name:  부의 추월차선 (10주년 스페셜 에디션) 부자들이 말해 주지 않는 진정한 부를 얻는 방법
# url: https://www.yes24.com//Product/Goods/106369008
# authors: 엠제이 드마코 저/신소영 역
# publisher: 토트출판사
# **********
#
# 8
# title: [생각에 관한 생각]
# full name:  생각에 관한 생각 우리의 행동을 지배하는 생각의 반란   [ 2판, 양장 ]
# url: https://www.yes24.com//Product/Goods/59580017
# authors: 대니얼 카너먼 저/이창신 역
# publisher: 김영사
# **********
#
# 9
# title: [머니 트렌드 2025]
# full name:  머니 트렌드 2025 새로운 부의 기회를 선점할 55가지 성공 시나리오   [ 예약구매특전 : 저자 8인 사인 인쇄본 & 탁상용 머니트리 달력 (책과랩핑) ]
# url: https://www.yes24.com//Product/Goods/132970116
# authors: 정태익,김도윤,김광석,김용섭,김현준,정수종,채상욱,최재붕 저
# publisher: 북모먼트
# **********
#
# 10
# title: [시대예보: 핵개인의 시대]
# full name:  시대예보: 핵개인의 시대    [ 양장 ]
# url: https://www.yes24.com//Product/Goods/122457906
# authors: 송길영 저
# publisher: 교보문고
# **********
#
# 11
# title: [트렌드 코리아 2024]
# full name:  트렌드 코리아 2024 청룡을 타고 비상하는 2024를 기원하며!
# url: https://www.yes24.com//Product/Goods/122426425
# authors: 김난도,전미영,최지혜,이수진,권정윤,한다혜,이준영,이향은,이혜원,추예린 저 외 1명
#
#
#
# 정보 더 보기/감추기
#
#
#
#
# 김난도
# 전미영
# 최지혜
# 이수진
# 권정윤
# 한다혜
# 이준영
# 이향은
# 이혜원
# 추예린
# 전다현
# publisher: 미래의창
# **********
#
# 12
# title: [AI 반도체 혁명]
# full name:  AI 반도체 혁명 3차 반도체 전쟁, 최후의 승자는 누가 될 것인가
# url: https://www.yes24.com//Product/Goods/132616188
# authors: 권순우,이동수,권세중,유지원 저
# publisher: 페이지2북스
# **********
#
# 13
# title: [경제기사 궁금증 300문 300답]
# full name:  경제기사 궁금증 300문 300답 불확실성의 시대, 경제기사 속에 답이 있다   [ 2023년 개정증보판 ]
# url: https://www.yes24.com//Product/Goods/117117772
# authors: 곽해선 저
# publisher: 혜다
# **********
#
# 14
# title: [챗봇 2025 트렌드&활용백과]
# full name:  챗봇 2025 트렌드&활용백과
# url: https://www.yes24.com//Product/Goods/126870580
# authors: 김덕진,서승완 저
# publisher: 스마트북스
# **********
#
# 15
# title: [자본주의 사용설명서]
# full name: EBS 다큐프라임 자본주의 사용설명서
# url: https://www.yes24.com//Product/Goods/13712404
# authors: 정지은,고희정 저
# publisher: 가나출판사
# **********
#
# 16
# title: [박태웅의 AI 강의 2025]
# full name:  박태웅의 AI 강의 2025 인공지능의 출현부터 일상으로의 침투까지 우리와 미래를 함께할 새로운 지능의 모든 것
# url: https://www.yes24.com//Product/Goods/133308510
# authors: 박태웅 저
# publisher: 한빛비즈
# **********
#
# 17
# title: [넛지: 파이널 에디션]
# full name:  넛지: 파이널 에디션 복잡한 세상에서 똑똑한 선택을 이끄는 힘   [ 양장, 개정판 ]
# url: https://www.yes24.com//Product/Goods/110157236
# authors: 리처드 탈러,캐스 선스타인 저/이경식 역/최정규 감수
# publisher: 리더스북
# **********
#
# 18
# title: [AI 2024]
# full name:  AI 2024 트렌드&활용백과
# url: https://www.yes24.com//Product/Goods/122880691
# authors: 김덕진 저
# publisher: 스마트북스
# **********
#
# 19
# title: [인센티브 이코노미]
# full name:  인센티브 이코노미 사람을 행동하게 하는 시그널에 관하여
# url: https://www.yes24.com//Product/Goods/133327244
# authors: 유리 그니지 저/안기순 역
# publisher: 김영사
# **********
